# %% [markdown]
# <a href="https://colab.research.google.com/github/palakuriswamy/III-H-assigements-/blob/main/AIML_Project_Module_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Project for Module 4: Perceptron and Gradient Descent
#
# NOTE: YOU NEED TO WRITE CODE IN CELLS THAT SPECIFICALLY MENTION TASK-1, TASK-2, etc.
#
# WRITE ANY OBSERVATION(S), IF REQUIRED BY THE TASK, IN A SEPARATE CELL AT THE BOTTOM OF THE NOTEBOOK.
#
# ---

# %% [markdown]
# # Notebook Imports and Packages

# %%
import matplotlib.pyplot as plt
import numpy as np

from mpl_toolkits.mplot3d.axes3d import Axes3D
from matplotlib import cm # color map

from sympy import symbols, diff
from math import log

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %matplotlib inline

# %% [markdown]
# # Example 1 - A simple cost function
#
# ## $$f(x) = x^2 + x + 1$$

# %%
def f(x):
    return x ** 2 + x + 1

# %%
# Make Data
x_1 = np.linspace(start=-3, stop=3, num=500)

# %%
# Plot
plt.xlim(-3, 3)
plt.ylim(0, 8)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)
plt.plot(x_1, f(x_1))
plt.show()

# %% [markdown]
# ## Slope & Derivatives
#
# Creating a function for the derivative of $f(x)$ called df(x)

# %%
def df(x):
    return 2 * x + 1

# %%
# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
##########################
##########################

## TASK-1 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Gradient Descent
new_x = 3
previous_x = 0
step_multiplier = 0.1
precision = 0.00001

x_list = [new_x]
slope_list = [df(new_x)]

for n in range(500):
    previous_x = new_x
    gradient = df(previous_x)  # [REQUIRED] Calculate the derivative (slope) at current x
    new_x = previous_x - step_multiplier * gradient  # [REQUIRED] Update x using the gradient and step_multiplier

    step_size = abs(new_x - previous_x)
    # print(step_size)

    x_list.append(new_x)
    slope_list.append(df(new_x))  # [REQUIRED] Calculate the derivative (slope) at the updated x

    if step_size < precision:
        print('Loop ran this many times:', n)
        break

print('Local minimum occurs at:', new_x)
print('Slope or df(x) value at this point is:', df(new_x))
print('f(x) value or cost at this point is:', f(new_x))
# Out:
# Loop ran this many times: 50
# Local minimum occurs at: -0.49996003706460423
# Slope or df(x) value at this point is: 7.992587079153068e-05
# f(x) value or cost at this point is: 0.7500000015970362

# %%
# Superimpose the gradient descent calculations on plot

plt.figure(figsize=[20, 5])

# 1 Chart: Cost function
plt.subplot(1, 3, 1)

plt.xlim(-3, 3)
plt.ylim(0, 8)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('f(x)', fontsize=16)

plt.plot(x_1, f(x_1), color='blue', linewidth=3, alpha=0.8)

values = np.array(x_list)
plt.scatter(x_list, f(values), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 3, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('df(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 3)
plt.ylim(-3, 6)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(x_list, slope_list, color='red', s=100, alpha=0.5)

# 3 Chart: Derivative (Close Up)
plt.subplot(1, 3, 3)

plt.title('Gradient Descent (close up)', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.grid()
plt.xlim(-0.55, -0.2)
plt.ylim(-0.3, 0.8)

plt.plot(x_1, df(x_1), color='skyblue', linewidth=6, alpha=0.8)
plt.scatter(x_list, slope_list, color='red', s=300, alpha=0.6)


plt.show()

# %% [markdown]
# # Example 2 - Multiple Minima vs Initial Guess & Advanced Functions
#
# ## $$g(x) = x^4 - 4x^2 + 5$$

# %%
##########################
##########################

## TASK-2 : Complete the lines of code wherever marked as [REQUIRED] in this cell.

##########################
##########################

# Make some data
x_2 = np.linspace(-2, 2, 1000)

def g(x):
    return x ** 4 - 4 * x ** 2 + 5  # [REQUIRED]

def dg(x):
    return 4 * x ** 3 - 8 * x  # [REQUIRED]

# %%
# TASK-3: Plot function and derivative side by side like has been done earlier

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0, 10)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='purple', linewidth=3)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-8, 8)

plt.plot(x_2, dg(x_2), color='magenta', linewidth=5)

plt.show()

# %% [markdown]
# ## Gradient Descent

# %%
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001,
                    max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# %%
local_min, list_x, deriv_list = gradient_descent(dg, 0.5, 0.02, 0.001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: 1.4122375085019094
# Number of steps: 23

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.5,
                                                 multiplier=0.01, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.4137636556157256
# Number of steps: 56

# %%
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= -0.1)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))
# Out:
# Local min occurs at: -1.4120887490901561
# Number of steps: 34

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 0)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

# %% [markdown]
# # Example 3 - Divergence and Overflow
#
# ## $$h(x) = x^5 - 2x^4 + 2$$

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import symbols, diff

# Gradient Descent Function
def gradient_descent(derivative_func, initial_guess, multiplier=0.02, precision=0.001, max_iter=300):
    new_x = initial_guess
    x_list = [new_x]
    slope_list = [derivative_func(new_x)]

    for n in range(max_iter):
        previous_x = new_x
        gradient = derivative_func(previous_x)
        new_x = previous_x - multiplier * gradient

        step_size = abs(new_x - previous_x)
        x_list.append(new_x)
        slope_list.append(derivative_func(new_x))

        if step_size < precision:
            break
    return new_x, x_list, slope_list

# Example 3 - Divergence and Overflow
h_x = symbols('h_x')
h = h_x**5 - 2*h_x**4 + 2

# Derivative of h(x)
dh_x = diff(h, h_x)

# Convert symbolic functions to Python functions
h = lambda x: x**5 - 2*x**4 + 2
dh = lambda x: 5*x**4 - 8*x**3

# Make some data
x_3 = np.linspace(-1.5, 2.5, 1000)

# Gradient Descent with adjusted parameters
local_min, list_x, deriv_list = gradient_descent(derivative_func=dh, initial_guess=-0.1, multiplier=0.001, precision=0.0001)
print('Local min occurs at:', local_min)
print('Number of steps:', len(list_x))

# Plot function and derivative side by side
plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-1.5, 2.5)
plt.ylim(-2, 5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('h(x)', fontsize=16)

plt.plot(x_3, h(x_3), color='green', linewidth=3, alpha=0.8)
plt.scatter(list_x, h(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dh(x)', fontsize=16)
plt.grid()
plt.xlim(-1.5, 2.5)
plt.ylim(-10, 10)

plt.plot(x_3, dh(x_3), color='lime', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()
# Out:
# Local min occurs at: -0.1000085
# Number of steps: 2

# %% [markdown]
# # The Learning Rate

# %%
# Calling gradient descent function
local_min, list_x, deriv_list = gradient_descent(derivative_func=dg, initial_guess= 1.9,
                                                multiplier=0.02, max_iter=500)

# Plot function and derivative and scatter plot side by side

plt.figure(figsize=[15, 5])

# 1 Chart: Cost function
plt.subplot(1, 2, 1)

plt.xlim(-2, 2)
plt.ylim(0.5, 5.5)

plt.title('Cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('g(x)', fontsize=16)

plt.plot(x_2, g(x_2), color='blue', linewidth=3, alpha=0.8)
plt.scatter(list_x, g(np.array(list_x)), color='red', s=100, alpha=0.6)

# 2 Chart: Derivative
plt.subplot(1, 2, 2)

plt.title('Slope of the cost function', fontsize=17)
plt.xlabel('X', fontsize=16)
plt.ylabel('dg(x)', fontsize=16)
plt.grid()
plt.xlim(-2, 2)
plt.ylim(-6, 8)

plt.plot(x_2, dg(x_2), color='skyblue', linewidth=5, alpha=0.6)
plt.scatter(list_x, deriv_list, color='red', s=100, alpha=0.5)

plt.show()

print('Number of steps is: ', len(list_x))
# Out:
# Number of steps is:  14

# %%
## TASK-5: Run gradient descent 3 times
# Experiment 1
local_min_1, list_x_1, deriv_list_1 = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.02, precision=0.0001, max_iter=n)

# Experiment 2
local_min_2, list_x_2, deriv_list_2 = gradient_descent(derivative_func=dg, initial_guess=-1, multiplier=0.02, precision=0.0001, max_iter=n)

# Experiment 3
local_min_3, list_x_3, deriv_list_3 = gradient_descent(derivative_func=dg, initial_guess=0.5, multiplier=0.02, precision=0.0001, max_iter=n)

## TASK-6: Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)
# Mid gamma
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)

# High gamma
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)

# Experiment
insane_gamma = gradient_descent(derivative_func=dg, initial_guess=1.9, multiplier=0.25, precision=0.0001, max_iter=n)
# Plotting for TASK-6: Plot two more learning rates: mid_gamma (0.001) and high_gamma (0.002)

# Mid gamma
mid_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.001, precision=0.0001, max_iter=n)
cost_values_mid = [calculate_cost(x) for x in mid_gamma[1]]

# High gamma
high_gamma = gradient_descent(derivative_func=dg, initial_guess=3, multiplier=0.002, precision=0.0001, max_iter=n)
cost_values_high = [calculate_cost(x) for x in high_gamma[1]]

# Plotting the reduction in cost over iterations for different learning rates
plt.figure(figsize=[15, 6])

# Mid gamma plot
plt.subplot(1, 2, 1)
plt.plot(range(len(mid_gamma[1])), cost_values_mid, marker='o', color='orange')
plt.title('Reduction in Cost over Iterations (Mid Gamma)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.grid(True)

# High gamma plot
plt.subplot(1, 2, 2)
plt.plot(range(len(high_gamma[1])), cost_values_high, marker='o', color='green')
plt.title('Reduction in Cost over Iterations (High Gamma)', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# TASK-7: Plot reduction in cost for each iteration

# Function to calculate the cost for a given x
def calculate_cost(x):
    return g(x)

# Calculate the cost for each iteration in the list_x
cost_values = [calculate_cost(x) for x in list_x]

# Plotting the reduction in cost over iterations
plt.figure(figsize=[10, 6])
plt.plot(range(len(list_x)), cost_values, marker='o', color='purple')
plt.title('Reduction in Cost over Iterations', fontsize=17)
plt.xlabel('Iteration', fontsize=16)
plt.ylabel('Cost', fontsize=16)
plt.grid(True)
plt.show()

# %% [markdown]
# # Example 4 - Data Viz with 3D Charts
#
# ## Minimise $$f(x, y) = \frac{1}{3^{-x^2 - y^2} + 1}$$
#
# Minimise $$f(x, y) = \frac{1}{r + 1}$$ where $r$ is $3^{-x^2 - y^2}$

# %%
import matplotlib.pyplot as plt
import numpy as np
from sympy import symbols, diff, lambdify
from mpl_toolkits.mplot3d import Axes3D

# Define symbols for x, y
x, y = symbols('x y')

# Define the cost function f(x, y)
f = 1 / (3 - x**2 - y**2) + 1

# Calculate the partial derivatives of f with respect to x and y
df_dx = diff(f, x)
df_dy = diff(f, y)

# Convert symbolic functions to Python functions
f_python = lambdify((x, y), f, 'numpy')
df_dx_python = lambdify((x, y), df_dx, 'numpy')
df_dy_python = lambdify((x, y), df_dy, 'numpy')

# Make some data
x_4 = np.linspace(-2, 2, 100)
y_4 = np.linspace(-2, 2, 100)
x_4, y_4 = np.meshgrid(x_4, y_4)
z_4 = f_python(x_4, y_4)

# Plot 3D surface
fig = plt.figure(figsize=[12, 8])
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x_4, y_4, z_4, cmap='viridis', alpha=0.8)
ax.set_xlabel('X', fontsize=16)
ax.set_ylabel('Y', fontsize=16)
ax.set_zlabel('f(x, y)', fontsize=16)
ax.set_title('3D Surface Plot of Cost Function', fontsize=18)

plt.show()

# Plot the gradient vectors on the 3D surface
fig = plt.figure(figsize=[12, 8])
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x_4, y_4, z_4, cmap='viridis', alpha=0.8)
ax.set_xlabel('X', fontsize=16)
ax.set_ylabel('Y', fontsize=16)
ax.set_zlabel('f(x, y)', fontsize=16)
ax.set_title('3D Surface Plot with Gradient Vectors', fontsize=18)

# Choose random points for gradient vectors
random_points_x = np.random.choice(x_4.flatten(), size=10)
random_points_y = np.random.choice(y_4.flatten(), size=10)
random_points_z = f_python(random_points_x, random_points_y)

# Calculate gradient vectors at random points
grad_vectors_x = -df_dx_python(random_points_x, random_points_y)
grad_vectors_y = -df_dy_python(random_points_x, random_points_y)
grad_vectors_z = np.zeros_like(grad_vectors_x)

ax.quiver(random_points_x, random_points_y, random_points_z,
          grad_vectors_x, grad_vectors_y, grad_vectors_z,
          color='red', length=0.1, normalize=True)

plt.show()

# %%
# Make our x and y data
x_4 = np.linspace(start=-2, stop=2, num=200)
y_4 = np.linspace(start=-2, stop=2, num=200)

print('Shape of X array', x_4.shape)

x_4, y_4 = np.meshgrid(x_4, y_4)
print('Array after meshgrid: ', x_4.shape)
# Out:
# Shape of X array (200,)
# Array after meshgrid:  (200, 200)

# %%
# Generating 3D Plot
fig = plt.figure(figsize=(16, 12))
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

ax.plot_surface(x_4, y_4, f_python(x_4, y_4), cmap='coolwarm', alpha=0.4)

plt.show()

# %% [markdown]
# ##########################
# ##########################
#
# ## TASK-9 : Complete the lines of text wherever marked as [REQUIRED] in this cell.
#
# ##########################
# ##########################
#
# ## Partial Derivatives & Symbolic Computation
#
# ## $$\frac{\partial f}{\partial x} = ## [REQUIRED]
#
# ## $$\frac{\partial f}{\partial y} = ## [REQUIRED]

# %%
# TASK-9: Complete the lines of text wherever marked as [REQUIRED] in this cell.
##########################

# Partial Derivatives & Symbolic Computation
# Calculate the partial derivatives of f with respect to x and y
df_dx = diff(f, x)
df_dy = diff(f, y)

# Convert symbolic expressions to Python functions
df_dx_python = lambdify((x, y), df_dx, 'numpy')
df_dy_python = lambdify((x, y), df_dy, 'numpy')

##########################

# %%
# Define symbols for x and y
x, y = symbols('x y')

# Define the cost function f(x, y)
f = 1 / (3 - x**2 - y**2) + 1

# Print cost function
print('Our cost function f(x, y) is:', f)

# Print partial derivatives with respect to x and y
df_dx = diff(f, x)
df_dy = diff(f, y)

print('Partial derivative wrt x is:', df_dx)
print('Partial derivative wrt y is:', df_dy)

# Evaluate the cost function and its partial derivatives at specific values
print('Value of f(x, y) at x=1.8, y=1.0 is:', f.evalf(subs={x: 1.8, y: 1.0}))
print('Value of partial derivative wrt x at x=1.8, y=1.0 is:', df_dx.evalf(subs={x: 1.8, y: 1.0}))
# Out:
# Our cost function f(x, y) is: 1 + 1/(-x**2 - y**2 + 3)
# Partial derivative wrt x is: 2*x/(-x**2 - y**2 + 3)**2
# Partial derivative wrt y is: 2*y/(-x**2 - y**2 + 3)**2
# Value of f(x, y) at x=1.8, y=1.0 is: 0.193548387096774
# Value of partial derivative wrt x at x=1.8, y=1.0 is: 2.34131113423517

# %% [markdown]
# ## Batch Gradient Descent with SymPy

# %%
# Setup
multiplier = 0.1
max_iter = 500
params = np.array([1.8, 1.0])  # initial guess

# Define symbolic variables
a, b = symbols('x y')

# Define the cost function
f = 1 / (3 - a**2 - b**2) + 1

for n in range(max_iter):
    gradient_x = diff(f, a).evalf(subs={a: params[0], b: params[1]})
    gradient_y = diff(f, b).evalf(subs={a: params[0], b: params[1]})
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f.evalf(subs={a: params[0], b: params[1]}))
# Out:
# Values in gradient array: [-0.00996899010795708 -0.00553832783775393]
# Minimum occurs at x value of: -5.19075604391038
# Minimum occurs at y value of: -2.88375335772799
# The cost is: 0.969001842338414

# %%
##########################
##########################

# TASK-10: Complete the lines of code wherever marked as [REQUIRED] in this cell.
##########################

# Partial derivative functions example 4
def fpx(x, y):
    return df_dx_python(x, y)  # Using previously defined df_dx_python

def fpy(x, y):
    return df_dy_python(x, y)  # Using previously defined df_dy_python

##########################

# %% [markdown]
# ## Graphing 3D Gradient Descent

# %%
# Setup
multiplier = 0.1
max_iter = 500
initial_guess = np.array([1.8, 1.0])  # initial guess

# Define symbolic variables
a, b = symbols('x y')

# Define the cost function symbolically
f_symbolic = 1 / (3 - a**2 - b**2) + 1

# Define the partial derivatives symbolically
df_dx_symbolic = diff(f_symbolic, a)
df_dy_symbolic = diff(f_symbolic, b)

# Convert symbolic expressions to Python functions
f_python = lambdify((a, b), f_symbolic, 'numpy')
df_dx_python = lambdify((a, b), df_dx_symbolic, 'numpy')
df_dy_python = lambdify((a, b), df_dy_symbolic, 'numpy')

# Gradient Descent
params = initial_guess.copy()

for n in range(max_iter):
    gradient_x = df_dx_python(params[0], params[1])
    gradient_y = df_dy_python(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients

# Results
print('Values in gradient array:', gradients)
print('Minimum occurs at x value of:', params[0])
print('Minimum occurs at y value of:', params[1])
print('The cost is:', f_python(params[0], params[1]))
# Out:
# Values in gradient array: [-0.00996899 -0.00553833]
# Minimum occurs at x value of: -5.190756043910358
# Minimum occurs at y value of: -2.883753357727976
# The cost is: 0.9690018423384137

# %%
# Setup
multiplier = 0.1
max_iter = 500
initial_guess = np.array([1.8, 1.0])  # initial guess

# Define symbolic variables
a, b = symbols('x y')

# Define the cost function symbolically
f_symbolic = 1 / (3 - a**2 - b**2) + 1

# Define the partial derivatives symbolically
df_dx_symbolic = diff(f_symbolic, a)
df_dy_symbolic = diff(f_symbolic, b)

# Convert symbolic expressions to Python functions
f_python = lambdify((a, b), f_symbolic, 'numpy')
df_dx_python = lambdify((a, b), df_dx_symbolic, 'numpy')
df_dy_python = lambdify((a, b), df_dy_symbolic, 'numpy')

# Gradient Descent
params = initial_guess.copy()
values_list = []

for n in range(max_iter):
    gradient_x = df_dx_python(params[0], params[1])
    gradient_y = df_dy_python(params[0], params[1])
    gradients = np.array([gradient_x, gradient_y])
    params = params - multiplier * gradients
    values_list.append(params)

# Convert the list to a NumPy array
values_array = np.array(values_list)

# Generating 3D Plot
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('X', fontsize=20)
ax.set_ylabel('Y', fontsize=20)
ax.set_zlabel('f(x, y) - Cost', fontsize=20)

x_4, y_4 = np.meshgrid(np.linspace(-6, 6, 100), np.linspace(-6, 6, 100))
ax.plot_surface(x_4, y_4, f_python(x_4, y_4), cmap='coolwarm', alpha=0.4)
ax.scatter(values_array[:, 0], values_array[:, 1],
           f_python(values_array[:, 0], values_array[:, 1]), s=50, color='red')

plt.show()

# %% [markdown]
# ## For Reference, practice and play with the code below
#
# # Example 5 - Working with Data & a Real Cost Function
#
# ## Mean Squared Error: a cost function for regression problems
#
# ### $$RSS = \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y^{(i)} - h_\theta x^{(i)} \big)^2 $$
# ### $$MSE = \frac{1}{n} \sum_{i=1}^{n} \big( y - \hat{y} \big)^2 $$

# %%
# Make sample data
x_5 = np.array([[0.1, 1.2, 2.4, 3.2, 4.1, 5.7, 6.5]]).transpose()
y_5 = np.array([1.7, 2.4, 3.5, 3.0, 6.1, 9.4, 8.2]).reshape(7, 1)

print('Shape of x_5 array:', x_5.shape)
print('Shape of y_5 array:', y_5.shape)
# Out:
# Shape of x_5 array: (7, 1)
# Shape of y_5 array: (7, 1)

# %%
# Quick linear regressino
regr = LinearRegression()
regr.fit(x_5, y_5)
print('Theta 0:', regr.intercept_[0])
print('Theta 1:', regr.coef_[0][0])
# Out:
# Theta 0: 0.8475351486029545
# Theta 1: 1.2227264637835913

# %%
plt.scatter(x_5, y_5, s=50)
plt.plot(x_5, regr.predict(x_5), color='orange', linewidth=3)
plt.xlabel('x values')
plt.ylabel('y values')
plt.show()

# %%
# y_hat = theta0 + theta1*x
y_hat = 0.847535148603 + 1.22272646378*x_5
print('Est values y_hat are: \n', y_hat)
print('In comparison, the actual y values are \n', y_5)
# Out:
# Est values y_hat are:
#  [[0.96980779]
#  [2.31480691]
#  [3.78207866]
#  [4.76025983]
#  [5.86071365]
#  [7.81707599]
#  [8.79525716]]
# In comparison, the actual y values are
#  [[1.7]
#  [2.4]
#  [3.5]
#  [3. ]
#  [6.1]
#  [9.4]
#  [8.2]]

# %%
# Challenge: Write a python function mse(y, y_hat) returns the MSE? Call the mse(y, y_hat)
# function and print out the MSE for the y_hat calculated above.

def mse(y, y_hat):
    #mse_calc = 1/7 * sum((y - y_hat)**2)
    #mse_calc = (1/y.size) * sum((y - y_hat)**2)
    mse_calc = np.average((y - y_hat)**2, axis=0)
    return mse_calc

# %%
print('Manually calculated MSE is:', mse(y_5, y_hat))
print('MSE regression using manual calc is', mean_squared_error(y_5, y_hat))
print('MSE regression is', mean_squared_error(y_5, regr.predict(x_5)))
# Out:
# Manually calculated MSE is: [0.94796558]
# MSE regression using manual calc is 0.947965575979458
# MSE regression is 0.9479655759794577

# %% [markdown]
# ## 3D Plot for the MSE Cost Function
#
# ### Make data for thetas

# %%
nr_thetas = 200
th_0 = np.linspace(start=-1, stop=3, num=nr_thetas)
th_1 = np.linspace(start=-1, stop=3, num=nr_thetas)
plot_t0, plot_t1 = np.meshgrid(th_0, th_1)

# %% [markdown]
# ### Calc MSE using nested for loops

# %%
plot_cost = np.zeros((nr_thetas, nr_thetas))

for i in range(nr_thetas):
    for j in range(nr_thetas):
        #print(plot_t0[j][i])
        y_hat = plot_t0[i][j] + plot_t1[i][j]*x_5
        plot_cost[i][j] = mse(y_5, y_hat)

print('Shape of plot_t0', plot_t0.shape)
print('Shape of plot_t1', plot_t1.shape)
print('Shape of plot_cost', plot_cost.shape)
# Out:
# Shape of plot_t0 (200, 200)
# Shape of plot_t1 (200, 200)
# Shape of plot_cost (200, 200)

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.hot)
plt.show()

# %%
print('Min value of plot_cost', plot_cost.min())
ij_min = np.unravel_index(plot_cost.argmin(), plot_cost.shape)
print('Min occurs at (i,j):', ij_min)
print('Min MSE for Theta 0 at plot_t0[111][91]', plot_t0[ij_min[0]][ij_min[1]])
print('Min MSE for Theta 1 at plot_t1[111][91]', plot_t1[ij_min[0]][ij_min[1]])
# Out:
# Min value of plot_cost 0.9483826526747164
# Min occurs at (i,j): (111, 91)
# Min MSE for Theta 0 at plot_t0[111][91] 0.829145728643216
# Min MSE for Theta 1 at plot_t1[111][91] 1.2311557788944723

# %% [markdown]
# ## Partial Derivatives of MSE w.r.t. $\theta_0$ and $\theta_1$
#
# ## $$\frac{\partial MSE}{\partial \theta_0} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big)$$
#
# ## $$\frac{\partial MSE}{\partial \theta_1} = - \frac{2}{n} \sum_{i=1}^{n} \big( y^{(i)} - \theta_0 - \theta_1 x^{(i)} \big) \big( x^{(i)} \big)$$

# %% [markdown]
# ## MSE & Gradient Descent

# %%
# x values, y values, array of theta parameters (theta0 at index 0 and theta1 at index 1)
def grad(x, y, thetas):
    n = y.size

    # Challenge: Create theta0_slope and theta1_slope to hold slope values from partial derivs
    theta0_slope = (-2/n) * sum(y - thetas[0] - thetas[1]*x)
    theta1_slope = (-2/n) * sum((y - thetas[0] - thetas[1]*x)*x)

    #return np.array([theta0_slope[0], theta1_slope[0]])
    #return np.append(arr=theta0_slope, values=theta1_slope)
    return np.concatenate((theta0_slope, theta1_slope), axis=0)

# %%
multiplier = 0.01
thetas = np.array([2.9, 2.9])

# Collect data points for scatter plot
plot_vals = thetas.reshape(1, 2)
mse_vals = mse(y_5, thetas[0] + thetas[1]*x_5)

for i in range(1000):
    thetas = thetas - multiplier * grad(x_5, y_5, thetas)

    # Append the new values to our numpy arrays
    plot_vals = np.concatenate((plot_vals, thetas.reshape(1, 2)), axis=0)
    mse_vals = np.append(arr=mse_vals, values=mse(y_5, thetas[0] + thetas[1]*x_5))

# Results
print('Min occurs at Theta 0:', thetas[0])
print('Min occurs at Theta 1:', thetas[1])
print('MSE is:', mse(y_5, thetas[0] + thetas[1]*x_5))
# Out:
# Min occurs at Theta 0: 0.8532230461743415
# Min occurs at Theta 1: 1.2214935332607393
# MSE is: [0.94797511]

# %%
# Plotting MSE
fig = plt.figure(figsize=[16, 12])
ax = fig.add_subplot(111, projection='3d')

ax.set_xlabel('Theta 0', fontsize=20)
ax.set_ylabel('Theta 1', fontsize=20)
ax.set_zlabel('Cost - MSE', fontsize=20)

ax.scatter(plot_vals[:, 0], plot_vals[:, 1], mse_vals, s=80, color='black')
ax.plot_surface(plot_t0, plot_t1, plot_cost, cmap=cm.rainbow, alpha=0.4)
plt.show()
